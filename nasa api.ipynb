# %%
from nasa import earth
from IPython.display import display
import os
#gets image from nasa api
os.environ["NASA_API_KEY"]="jAYO3dDATho4i4Ohrb65Br7xPkDK6QWOmY5Pjyq6"
assets = earth.assets(lat=34.14, lon=-118.25, begin='2017-02-01', end='2017-06-01')
for a in assets:
    display(a.get_asset_image().image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7FD6CD569898>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7FD6CD569898>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7FD6E00F5198>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7FD6CC056F60>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7FD6E00F5198>
