# %%
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import matplotlib.pyplot as plt
'''This code creates a double axis graph comparing the asthma rates and aerosol content over time'''
host = host_subplot(111, axes_class=AA.Axes)
plt.subplots_adjust(right=0.75)
font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        } #adjusts title style
par1 = host.twinx()
host.set_xlim(2005, 2015)
host.set_ylim(0, .1) #range for y-axis one
host.set_xlabel("Year")
host.set_ylabel("Asthma Rates (US Total)") #axis one
par1.set_ylabel("Average Aerosol Fraction") #axis two
#data points
p1, = host.plot([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,2015], [.087, .09, .085, .082, .093, .094, .088, .093, .085, .084, .079], label="Northeast",linestyle='dashed')
p1, = host.plot([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,2015], [.077, .083, .082, .086, .088, .087, .082, .083, .073, .079, .079], label="Midwest",linestyle='dashed')
p1, = host.plot([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,2015], [.072, .073, .073, .07, .075, .083, .083, .081, .068, .075, .076], label="South",linestyle='dashed')
p1, = host.plot([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,2015], [.075, .072, .073, .08, .077, .083, .083, .078, .072, .073, .079], label="West",linestyle='dashed')
p2, = par1.plot([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,2015,2016,2017], [0.1578671115164649, 0.15201806422778805, 0.14545704938820161,0.1549062099680654,0.133278246792898,0.14283394266322635,0.1409409924411912,0.15997702995200716,0.1480814553240362, 0.1362885183539518,0.10655997547089897,0.14073311870369937,0.12912207125392036], label="Aerosol Content",)
par1.set_ylim(0, .2) #range from y-axis two
host.legend(loc=3)
host.axis["left"].label.set_color(p1.get_color())
par1.axis["right"].label.set_color(p2.get_color())
plt.axvspan(2013, 2013.03, facecolor='g', alpha=0.5, )
plt.text(2012.9,.037,"Obama's Executive Order to Mitigate Effects of Climate Change",fontweight="bold",rotation=90,verticalalignment="center",horizontalalignment="center")
plt.title("Asthma Rates and Aerosol Content (2005-2015)",fontdict=font)
plt.figure(figsize=(11,9))
plt.draw()
plt.show()

# %%
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import matplotlib.pyplot as plt
'''This code creates a double axis graph comparing the COPD rates and aerosol content over time'''
host = host_subplot(111, axes_class=AA.Axes)
plt.subplots_adjust(right=0.75)
font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        } #adjusts title type
par1 = host.twinx()
host.set_xlim(2005, 2011)
host.set_ylim(0, .1) #range for y-axis one
host.set_xlabel("Year")
host.set_ylabel("COPD Rates (US Total)")#axis one
par1.set_ylabel("Average Aerosol Fraction")#axis two
#data point
p1, = host.plot([2005, 2006, 2007, 2008, 2009, 2010, 2011], [.056, .059, .05, .058, .062, .058, .059], label="US Total COPD",linestyle='dashed')
p2, = par1.plot([2005, 2006, 2007, 2008, 2009, 2010, 2011], [0.1578671115164649, 0.15201806422778805, 0.14545704938820161,0.1549062099680654,0.133278246792898,0.14283394266322635,0.1409409924411912,], label="Aerosol Content",)
par1.set_ylim(0, .2) #range for y-axis two
host.legend(loc=3)
host.axis["left"].label.set_color(p1.get_color())
par1.axis["right"].label.set_color(p2.get_color())
plt.title("COPD Rates and Aerosol Content (2005-2011)",fontdict=font)
plt.figure(figsize=(11,9))
plt.draw()
plt.show()

# %%
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import matplotlib.pyplot as plt
'''This code creates a double axis graph comparing the COPD and aerosol content over time. However, it is shifted to
consider the time required to contract the disease'''
host = host_subplot(111, axes_class=AA.Axes)
plt.subplots_adjust(right=0.75)
font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        } #adjusts title type
par1 = host.twinx()
host.set_xlim(2005, 2011) #range for y-axis one
host.set_ylim(0, .1)
host.set_xlabel("Year")
host.set_ylabel("COPD Rates (US Total)")#axis one
par1.set_ylabel("Average Aerosol Fraction")#axis two
#data point
p1, = host.plot([2007, 2008, 2009, 2010, 2011, 2012, 2013], [.056, .059, .05, .058, .062, .058, .059], label="US Total COPD",linestyle='dashed')
p2, = par1.plot([2005, 2006, 2007, 2008, 2009, 2010, 2011], [0.1578671115164649, 0.15201806422778805, 0.14545704938820161,0.1549062099680654,0.133278246792898,0.14283394266322635,0.1409409924411912,], label="Aerosol Content",)
par1.set_ylim(0, .2)#range for y-axis two
host.legend(loc=3)
host.axis["left"].label.set_color(p1.get_color())
par1.axis["right"].label.set_color(p2.get_color())
plt.title("COPD Rates and Aerosol Content (2005-2011)",fontdict=font)
plt.figure(figsize=(11,9))
plt.draw()
plt.show()
