# %%
import urllib.request
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
def fraction_purple_pixels(image):
    '''This counts the amount of purple pixels in the image using RGB values 
    and takes the amount of purple pixels
    as a fraction over the total amount of pixels.
    We can predict the over all amount of severe aerosol depth using this.'''
    im = Image.open(image)
    image_dimensions_in_pixels=im.size[0]*im.size[1]
    colors=im.convert('RGB').getcolors(image_dimensions_in_pixels) #converts image to rgb then gets colors
    n_pixels_closeto_white=0
    for pixel_count,color in colors:
        if color[0]>color[1] and color[2]>color[1]: # this is checking if it's purple
            n_pixels_closeto_white+=pixel_count
    return n_pixels_closeto_white/image_dimensions_in_pixels
def fraction_blue_pixels(image):
    '''This counts the amount of blue pixels in the image using RGB values 
    and takes the amount of purple pixels
    as a fraction over the total amount of pixels.
    We can predict the over all amount of severe aerosol depth using this.'''
    im = Image.open(image)
    image_dimensions_in_pixels=im.size[0]*im.size[1]
    colors=im.convert('RGB').getcolors(image_dimensions_in_pixels) #converts image to rgb then gets colors
    n_pixels_closeto_white=0
    for pixel_count,color in colors:
        if color[0]>42 and color[1]>47 and color[2]>120: # this is checking if it's blue
            n_pixels_closeto_white+=pixel_count
    return n_pixels_closeto_white/image_dimensions_in_pixels
def aerosol_image(date):
    '''This code gets the images from nasa satellites and allows us to input a date in the function parameters
    the date is in the format YEAR + day of the year.'''
    name = date
    ful_name = "aerosol "+ str(name)+".jpg"
    url="https://gibs.earthdata.nasa.gov/image-download?TIME="+str(date)+"&extent=-151.5023958280347,2.061881667674527,-55.87739582803471,71.53063166767453&epsg=4326&layers=BlueMarble_ShadedRelief,Coastlines,MODIS_Aqua_Angstrom_Exponent_Land&opacities=1,1,1&worldfile=false&format=image/jpeg&width=1098&height=701"
    urllib.request.urlretrieve(url, ful_name)
    img=mpimg.imread(ful_name)
    imgplot = plt.imshow(img)
    plt.title(date)
    f=fraction_purple_pixels(ful_name)
    print("Fraction Severe Aerosol Depth",f)
    fr=fraction_blue_pixels(ful_name)
    print("Fraction Medium Aerosol Depth",fr)      
    plt.show()
#2005
aerosol_image("2005166")
#2006
aerosol_image("2006166")
#2007
aerosol_image("2007166")
#2008
aerosol_image("2008166")
#2009
aerosol_image("2009166")
#2010
aerosol_image("2010166")
#2011
aerosol_image("2011166")
#2012
aerosol_image("2012166")
#2013
aerosol_image("2013166")
#2014
aerosol_image("2014166")
#2015
aerosol_image("2015166")
#2016
aerosol_image("2016166")
#2017
aerosol_image("2017166")
# Out:
# Fraction Severe Aerosol Depth 0.02024300439912797
# Fraction Medium Aerosol Depth 0.1578671115164649
# Fraction Severe Aerosol Depth 0.031815075523127255
# Fraction Medium Aerosol Depth 0.15201806422778805
# Fraction Severe Aerosol Depth 0.03228928748678053
# Fraction Medium Aerosol Depth 0.14545704938820161
# Fraction Severe Aerosol Depth 0.022065797234759606
# Fraction Medium Aerosol Depth 0.1549062099680654
# Fraction Severe Aerosol Depth 0.03009881797796019
# Fraction Medium Aerosol Depth 0.133278246792898
# Fraction Severe Aerosol Depth 0.025928351119529996
# Fraction Medium Aerosol Depth 0.14283394266322635
# Fraction Severe Aerosol Depth 0.030336573565216487
# Fraction Medium Aerosol Depth 0.1409409924411912
# Fraction Severe Aerosol Depth 0.020730208471374488
# Fraction Medium Aerosol Depth 0.15997702995200716
# Fraction Severe Aerosol Depth 0.02755106548282573
# Fraction Medium Aerosol Depth 0.1480814553240362
# Fraction Severe Aerosol Depth 0.02296615036027117
# ...

# %%
import urllib.request
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image

# North East
def fraction_purple_pixels(image):
    '''This counts the amount of purple pixels in the image using RGB values 
    and takes the amount of purple pixels
    as a fraction over the total amount of pixels.
    We can predict the over all amount of severe aerosol depth using this.
    '''
    im = Image.open(image)
    image_dimensions_in_pixels=im.size[0]*im.size[1]
    colors=im.convert('RGB').getcolors(image_dimensions_in_pixels) #converts image to rgb then gets colors
    n_pixels_closeto_white=0
    for pixel_count,color in colors:
        if color[0]>color[1] and color[2]>color[1]: # this is checking if it's purple
            n_pixels_closeto_white+=pixel_count
    return n_pixels_closeto_white/image_dimensions_in_pixels
def fraction_blue_pixels(image):
    '''This counts the amount of blue pixels in the image using RGB values 
    and takes the amount of purple pixels
    as a fraction over the total amount of pixels.
    We can predict the over all amount of severe aerosol depth using this.'''
    im = Image.open(image)
    image_dimensions_in_pixels=im.size[0]*im.size[1]
    colors=im.convert('RGB').getcolors(image_dimensions_in_pixels) #converts image to rgb then gets colors
    n_pixels_closeto_white=0
    for pixel_count,color in colors:
        if color[0]>42 and color[1]>47 and color[2]>120: # this is checking if it's blue
            n_pixels_closeto_white+=pixel_count
    return n_pixels_closeto_white/image_dimensions_in_pixels
def aerosol_image(date):
    '''This code gets the images from nasa satellites and allows us to input a date in the function parameters
    the date is in the format YEAR + day of the year.'''
    name = date
    ful_name = "aerosol Northeast"+ str(name)+".jpg"
    url="https://gibs.earthdata.nasa.gov/image-download?TIME="+str(date)+"&extent=-89.68518354987714,34.27366572201048,-67.74420823647196,47.943241611711315&epsg=4326&layers=BlueMarble_ShadedRelief,Coastlines,MODIS_Aqua_Angstrom_Exponent_Land&opacities=1,1,1&worldfile=false&format=image/jpeg&width=1098&height=701"
    urllib.request.urlretrieve(url, ful_name)
    img=mpimg.imread(ful_name)
    imgplot = plt.imshow(img)
    plt.title(date)
    f=fraction_purple_pixels(ful_name)
    print("Fraction Severe Aerosol Depth",f)
    fr=fraction_blue_pixels(ful_name)
    print("Fraction Medium Aerosol Depth",fr)      
    plt.show()
#2005
aerosol_image("2005166")
#2006
aerosol_image("2006166")
#2007
aerosol_image("2007166")
#2008
aerosol_image("2008166")
#2009
aerosol_image("2009166")
#2010
aerosol_image("2010166")
#2011
aerosol_image("2011166")
#2012
aerosol_image("2012166")
#2013
aerosol_image("2013166")
#2014
aerosol_image("2014166")
#2015
aerosol_image("2015166")

# %%
import urllib.request
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
# South
def fraction_purple_pixels(image):
   '''This counts the amount of purple pixels in the image using RGB values 
    and takes the amount of purple pixels
    as a fraction over the total amount of pixels.
    We can predict the over all amount of severe aerosol depth using this.'''
    im = Image.open(image)
    image_dimensions_in_pixels=im.size[0]*im.size[1]
    colors=im.convert('RGB').getcolors(image_dimensions_in_pixels) #converts image to rgb then gets colors
    n_pixels_closeto_white=0
    for pixel_count,color in colors:
        if color[0]>color[1] and color[2]>color[1]: # this is checking if it's purple
            n_pixels_closeto_white+=pixel_count
    return n_pixels_closeto_white/image_dimensions_in_pixels
def fraction_blue_pixels(image):
    '''This counts the amount of blue pixels in the image using RGB values 
    and takes the amount of purple pixels
    as a fraction over the total amount of pixels.
    We can predict the over all amount of severe aerosol depth using this.'''
    im = Image.open(image)
    image_dimensions_in_pixels=im.size[0]*im.size[1]
    colors=im.convert('RGB').getcolors(image_dimensions_in_pixels) #converts image to rgb then gets colors
    n_pixels_closeto_white=0
    for pixel_count,color in colors:
        if color[0]>42 and color[1]>47 and color[2]>120: # this is checking if it's blue
            n_pixels_closeto_white+=pixel_count
    return n_pixels_closeto_white/image_dimensions_in_pixels
def aerosol_image(date):
    '''This code gets the images from nasa satellites and allows us to input a date in the function parameters
    the date is in the format YEAR + day of the year.'''
    name = date
    ful_name = "aerosol South"+ str(name)+".jpg"
    url="https://gibs.earthdata.nasa.gov/image-download?TIME="+str(date)+"&extent=-109.44947480441274,25.30572739946789,-74.88373194956412,38.97530328916872&epsg=4326&layers=BlueMarble_ShadedRelief,Coastlines,MODIS_Aqua_Angstrom_Exponent_Land&opacities=1,1,1&worldfile=false&format=image/jpeg&width=1098&height=701"
    urllib.request.urlretrieve(url, ful_name)
    img=mpimg.imread(ful_name)
    imgplot = plt.imshow(img)
    plt.title(date)
    f=fraction_purple_pixels(ful_name)
    print("Fraction Severe Aerosol Depth",f)
    fr=fraction_blue_pixels(ful_name)
    print("Fraction Medium Aerosol Depth",fr)      
    plt.show()
#2005
aerosol_image("2005166")
#2006
aerosol_image("2006166")
#2007
aerosol_image("2007166")
#2008
aerosol_image("2008166")
#2009
aerosol_image("2009166")
#2010
aerosol_image("2010166")
#2011
aerosol_image("2011166")
#2012
aerosol_image("2012166")
#2013
aerosol_image("2013166")
#2014
aerosol_image("2014166")
#2015
aerosol_image("2015166")

# %%
import urllib.request
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
def fraction_purple_pixels(image):
# West
   '''This counts the amount of purple pixels in the image using RGB values 
    and takes the amount of purple pixels
    as a fraction over the total amount of pixels.
    We can predict the over all amount of severe aerosol depth using this.'''
    im = Image.open(image)
    image_dimensions_in_pixels=im.size[0]*im.size[1]
    colors=im.convert('RGB').getcolors(image_dimensions_in_pixels) #converts image to rgb then gets colors
    n_pixels_closeto_white=0
    for pixel_count,color in colors:
        if color[0]>color[1] and color[2]>color[1]: # this is checking if it's purple
            n_pixels_closeto_white+=pixel_count
    return n_pixels_closeto_white/image_dimensions_in_pixels

def fraction_blue_pixels(image):
    '''This counts the amount of blue pixels in the image using RGB values 
    and takes the amount of purple pixels
    as a fraction over the total amount of pixels.
    We can predict the over all amount of severe aerosol depth using this.'''
    im = Image.open(image)
    image_dimensions_in_pixels=im.size[0]*im.size[1]
    colors=im.convert('RGB').getcolors(image_dimensions_in_pixels) #converts image to rgb then gets colors
    n_pixels_closeto_white=0
    for pixel_count,color in colors:
        if color[0]>42 and color[1]>47 and color[2]>120: # this is checking if it's blue
            n_pixels_closeto_white+=pixel_count
    return n_pixels_closeto_white/image_dimensions_in_pixels

def aerosol_image(date):
    '''This code gets the images from nasa satellites and allows us to input a date in the function parameters
    the date is in the format YEAR + day of the year.'''
    name = date
    ful_name = "aerosol West"+ str(name)+".jpg"
    url="https://gibs.earthdata.nasa.gov/image-download?TIME="+str(date)+"&extent=-125.03453266591879,33.83832891023656,-104.39956778783537,49.075117322323486&epsg=4326&layers=BlueMarble_ShadedRelief,Coastlines,MODIS_Aqua_Angstrom_Exponent_Land&opacities=1,1,1&worldfile=false&format=image/jpeg&width=1098&height=701"
    urllib.request.urlretrieve(url, ful_name)
    img=mpimg.imread(ful_name)
    imgplot = plt.imshow(img)
    plt.title(date)
    f=fraction_purple_pixels(ful_name)
    print("Fraction Severe Aerosol Depth",f)
    fr=fraction_blue_pixels(ful_name)
    print("Fraction Medium Aerosol Depth",fr)      
    plt.show()
#2005
aerosol_image("2005166")
#2006
aerosol_image("2006166")
#2007
aerosol_image("2007166")
#2008
aerosol_image("2008166")
#2009
aerosol_image("2009166")
#2010
aerosol_image("2010166")
#2011
aerosol_image("2011166")
#2012
aerosol_image("2012166")
#2013
aerosol_image("2013166")
#2014
aerosol_image("2014166")
#2015
aerosol_image("2015166")

# %%
import urllib.request
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
def fraction_purple_pixels(image):
# Midwest
   '''This counts the amount of purple pixels in the image using RGB values 
    and takes the amount of purple pixels
    as a fraction over the total amount of pixels.
    We can predict the over all amount of severe aerosol depth using this.'''
    im = Image.open(image)
    image_dimensions_in_pixels=im.size[0]*im.size[1]
    colors=im.convert('RGB').getcolors(image_dimensions_in_pixels) #converts image to rgb then gets colors
    n_pixels_closeto_white=0
    for pixel_count,color in colors:
        if color[0]>color[1] and color[2]>color[1]: # this is checking if it's purple
            n_pixels_closeto_white+=pixel_count
    return n_pixels_closeto_white/image_dimensions_in_pixels
def fraction_blue_pixels(image):
    '''This counts the amount of blue pixels in the image using RGB values 
    and takes the amount of purple pixels
    as a fraction over the total amount of pixels.
    We can predict the over all amount of severe aerosol depth using this.'''
    im = Image.open(image)
    image_dimensions_in_pixels=im.size[0]*im.size[1]
    colors=im.convert('RGB').getcolors(image_dimensions_in_pixels) #converts image to rgb then gets colors
    n_pixels_closeto_white=0
    for pixel_count,color in colors:
        if color[0]>42 and color[1]>47 and color[2]>120: # this is checking if it's blue
            n_pixels_closeto_white+=pixel_count
    return n_pixels_closeto_white/image_dimensions_in_pixels
def aerosol_image(date):
    '''This code gets the images from nasa satellites and allows us to input a date in the function parameters
    the date is in the format YEAR + day of the year.'''
    name = date
    ful_name = "aerosol Midwest"+ str(name)+".jpg"
    url="https://gibs.earthdata.nasa.gov/image-download?TIME="+str(date)+"&extent=-102.83235526544928,34.709002533784385,-79.06296534259367,49.94579094587131&epsg=4326&layers=BlueMarble_ShadedRelief,Coastlines,MODIS_Aqua_Angstrom_Exponent_Land&opacities=1,1,1&worldfile=false&format=image/jpeg&width=1098&height=701"
    urllib.request.urlretrieve(url, ful_name)
    img=mpimg.imread(ful_name)
    imgplot = plt.imshow(img)
    plt.title(date)
    f=fraction_purple_pixels(ful_name)
    print("Fraction Severe Aerosol Depth",f)
    fr=fraction_blue_pixels(ful_name)
    print("Fraction Medium Aerosol Depth",fr)      
    plt.show()
#2005
aerosol_image("2005166")
#2006
aerosol_image("2006166")
#2007
aerosol_image("2007166")
#2008
aerosol_image("2008166")
#2009
aerosol_image("2009166")
#2010
aerosol_image("2010166")
#2011
aerosol_image("2011166")
#2012
aerosol_image("2012166")
#2013
aerosol_image("2013166")
#2014
aerosol_image("2014166")
#2015
aerosol_image("2015166")
